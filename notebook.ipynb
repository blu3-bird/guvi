# %%
print('hello')
# Out:
# hello

# %%
import pandas as pd

# %%
person = {
    'name': ['pardeep','arson','ace'],
    'age': [22,22,12]
}
person_df = pd.DataFrame(person)

# %%
df = pd.read_excel('movies_data.xlsx')
df.head()
# Out:
# /home/arson/.cache/pypoetry/virtualenvs/arson-guvi-NQVoKMHS-py3.12/lib/python3.12/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#                                                Title  Year  \
# 0  Intolerance: Love's Struggle Throughout the Ages   1916
# 1                    Over the Hill to the Poorhouse   1920
# 2                                    The Big Parade   1925
# 3                                        Metropolis   1927
# 4                                     Pandora's Box   1929
#
#                 Genres Language  Country Content Rating  Duration  \
# 0    Drama|History|War      NaN      USA      Not Rated       123
# 1          Crime|Drama      NaN      USA            NaN       110
# 2    Drama|Romance|War      NaN      USA      Not Rated       151
# 3         Drama|Sci-Fi   German  Germany      Not Rated       145
# 4  Crime|Drama|Romance   German  Germany      Not Rated       110
#
# ...

# %%
df.Title
# Out:
# 0       Intolerance: Love's Struggle Throughout the Ages
# 1                         Over the Hill to the Poorhouse
# 2                                         The Big Parade
# 3                                             Metropolis
# 4                                          Pandora's Box
#                               ...
# 1333                                    Twin Falls Idaho
# 1334                       Universal Soldier: The Return
# 1335                                       Varsity Blues
# 1336                                      Wild Wild West
# 1337                                      Wing Commander
# Name: Title, Length: 1338, dtype: str

# %%
df_subset= df[['Title','Year','Genres']]
df_subset
# Out:
#                                                   Title  Year  \
# 0     Intolerance: Love's Struggle Throughout the Ages   1916
# 1                       Over the Hill to the Poorhouse   1920
# 2                                       The Big Parade   1925
# 3                                           Metropolis   1927
# 4                                        Pandora's Box   1929
# ...                                                 ...   ...
# 1333                                  Twin Falls Idaho   1999
# 1334                     Universal Soldier: The Return   1999
# 1335                                     Varsity Blues   1999
# 1336                                    Wild Wild West   1999
# 1337                                    Wing Commander   1999
#
#                             Genres
# 0                Drama|History|War
# 1                      Crime|Drama
# 2                Drama|Romance|War
# 3                     Drama|Sci-Fi
# 4              Crime|Drama|Romance
# ...

# %% [markdown]
# ### Loc Function

# %%
df.loc[0]
# Out:
# Title                          Intolerance: Love's Struggle Throughout the Ages
# Year                                                                        1916
# Genres                                                         Drama|History|War
# Language                                                                     NaN
# Country                                                                      USA
# Content Rating                                                         Not Rated
# Duration                                                                     123
# Aspect Ratio                                                                1.33
# Budget                                                                  385907.0
# Gross Earnings                                                               NaN
# Director                                                           D.W. Griffith
# Actor 1                                                             Lillian Gish
# ...

# %%
## to access the last row, 
df.loc[df.shape[0]]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/.cache/pypoetry/virtualenvs/arson-guvi-NQVoKMHS-py3.12/lib/python3.12/site-packages/pandas/core/indexes/range.py:521, in RangeIndex.get_loc(self, key)
#     520 try:
# --> 521     return self._range.index(new_key)
#     522 except ValueError as err:
#
# ValueError: 1338 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[86], line 2
#       1 ## to access the last row,
# ----> 2 df.loc[df.shape[0]]
#
# File ~/.cache/pypoetry/virtualenvs/arson-guvi-NQVoKMHS-py3.12/lib/python3.12/site-packages/pandas/core/indexing.py:1207, in _LocationIndexer.__getitem__(self, key)
#    1205 maybe_callable = com.apply_if_callable(key, self.obj)
# ...

# %%
# 0th , 99th and last

df.loc[[0,99,df.shape[0]-1]]
# Out:
#                                                   Title  Year  \
# 0     Intolerance: Love's Struggle Throughout the Ages   1916
# 99                                  A Hard Day's Night   1964
# 1337                                    Wing Commander   1999
#
#                        Genres Language Country Content Rating  Duration  \
# 0           Drama|History|War      NaN     USA      Not Rated       123
# 99             Comedy|Musical  English      UK       Approved        87
# 1337  Action|Adventure|Sci-Fi  English     USA          PG-13       100
#
#       Aspect Ratio      Budget  Gross Earnings  ... Facebook Likes - Actor 1  \
# 0             1.33    385907.0             NaN  ...                      436
# 99            1.75    560000.0        515005.0  ...                      785
# 1337          2.35  30000000.0      11576087.0  ...                      811
#
#      Facebook Likes - Actor 2 Facebook Likes - Actor 3  \
# 0                          22                      9.0
# ...

# %% [markdown]
# ### iloc function

# %%
df_iloc = df.iloc[[0,99,-1]]
df_iloc
# Out:
#                                                   Title  Year  \
# 0     Intolerance: Love's Struggle Throughout the Ages   1916
# 99                                  A Hard Day's Night   1964
# 1337                                    Wing Commander   1999
#
#                        Genres Language Country Content Rating  Duration  \
# 0           Drama|History|War      NaN     USA      Not Rated       123
# 99             Comedy|Musical  English      UK       Approved        87
# 1337  Action|Adventure|Sci-Fi  English     USA          PG-13       100
#
#       Aspect Ratio      Budget  Gross Earnings  ... Facebook Likes - Actor 1  \
# 0             1.33    385907.0             NaN  ...                      436
# 99            1.75    560000.0        515005.0  ...                      785
# 1337          2.35  30000000.0      11576087.0  ...                      811
#
#      Facebook Likes - Actor 2 Facebook Likes - Actor 3  \
# 0                          22                      9.0
# ...

# %%
# to get the exact cell
df.iloc[3,1]
# Out:
# np.int64(1927)

# %%
df.iloc[1:4,1]
# Out:
# 1    1920
# 2    1925
# 3    1927
# Name: Year, dtype: int64

# %%
df.iloc[[2,4,6,8],[1,5]]
# Out:
#    Year Content Rating
# 2  1925      Not Rated
# 4  1929      Not Rated
# 6  1930         Passed
# 8  1933        Unrated

# %%
group_df = df.groupby('Year')['IMDB Score'].mean()
group_df.tail()
# Out:
# Year
# 1995    6.565714
# 1996    6.418182
# 1997    6.485593
# 1998    6.485821
# 1999    6.407143
# Name: IMDB Score, dtype: float64

# %%
df_1 =df.groupby(['Country','Year'])[['IMDB Score','Duration']].mean()
df_1.tail(10)
# Out:
#                    IMDB Score    Duration
# Country      Year
# USA          1993    6.678947  122.789474
#              1994    6.673333  112.644444
#              1995    6.561667  113.950000
#              1996    6.367442  110.662791
#              1997    6.400000  111.765957
#              1998    6.418000  110.420000
#              1999    6.326515  107.924242
# West Germany 1967    6.000000   80.000000
#              1981    8.400000  293.000000
#              1984    7.400000   94.000000

# %%
# unique content rat9ng
df.groupby('Country')['Content Rating'].nunique()
df.groupby('Country')['Content Rating'].value_counts()
# Out:
# Country       Content Rating
# Aruba         R                 1
# Australia     R                 8
#               PG-13             5
#               PG                3
#               G                 2
#                                ..
# USA           NC-17             3
#               TV-G              1
# West Germany  R                 1
#               PG                1
#               M                 1
# Name: count, Length: 78, dtype: int64

# %%
df['IMDB Score'].agg(['sum','mean','min'])
# Out:
# sum     8967.500000
# mean       6.702167
# min        2.300000
# Name: IMDB Score, dtype: float64

# %%
df.groupby('Country')['IMDB Score'].agg(['sum','mean','min']).head()
# Out:
#              sum      mean  min
# Country
# Aruba        4.8  4.800000  4.8
# Australia  116.2  6.455556  4.9
# Brazil      14.4  7.200000  6.4
# Canada     158.4  6.336000  2.8
# China        7.8  7.800000  7.8

# %% [markdown]
# ### Creatign and manupulating the dataframe

# %%
data = ['arson',22,'M']
index = ['name','age','Gender']

s= pd.Series(data, index=index)

# %%
s.loc['name']
# Out:
# 'arson'

# %%
s.iloc[0]
# Out:
# 'arson'

# %%
person_df
# Out:
#       name  age
# 0  pardeep   40
# 1    arson   40
# 2      ace   40

# %%
person_df['age'][0] = 12
# Out:
# /tmp/ipykernel_1452353/992076656.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   person_df['age'][0] = 12

# %%
person_df
# Out:
#       name  age
# 0  pardeep   22
# 1    arson   22
# 2      ace   12

# %%
df_A = [{
    'name':'A',
    'age': 'B'
},index=[0,1]]

df_B = [{
    'name':'A',
    'age': 'B'
},index=[2,3]]

df_C= [{
    'name':'A',
    'age': 'B'
},index=[4,5]]
# Out:
#   Cell In[93], line 4
#     },index=[0,1]]
#       ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?
